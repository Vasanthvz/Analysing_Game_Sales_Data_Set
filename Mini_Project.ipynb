# %% [markdown]
# <a href="https://colab.research.google.com/github/Vasanthvz/Analysing-movie-data-set-using-python/blob/main/Mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt

path = "/content/drive/MyDrive/FODS Mini Project/Data Science Mini project/Analysing-movie-data-set-using-python/vgsales.csv"
d = pd.read_csv(path)
print(d)
d.info()
d.shape
d.describe()
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
d.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
d.head(20)
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# ...

# %%
d.tail()
# Out:
#         Rank                                              Name Platform  \
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year     Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16593  2002.0  Platform       Kemco      0.01      0.00       0.0
# 16594  2003.0   Shooter  Infogrames      0.01      0.00       0.0
# 16595  2008.0    Racing  Activision      0.00      0.00       0.0
# 16596  2010.0    Puzzle    7G//AMES      0.00      0.01       0.0
# 16597  2003.0  Platform     Wanadoo      0.01      0.00       0.0
#
#        Other_Sales  Global_Sales
# 16593          0.0          0.01
# 16594          0.0          0.01
# ...

# %%
d.tail(20)
# Out:
#         Rank                                               Name Platform  \
# 16578  16581                      Outdoors Unleashed: Africa 3D      3DS
# 16579  16582                                  PGA European Tour      N64
# 16580  16583                                          Real Rode      PS2
# 16581  16584                                          Fit & Fun      Wii
# 16582  16585                                    Planet Monsters      GBA
# 16583  16586                                     Carmageddon 64      N64
# 16584  16587                                   Bust-A-Move 3000       GC
# 16585  16588                                             Breach       PC
# 16586  16589                     Secret Files 2: Puritas Cordis       DS
# 16587  16590                           Mezase!! Tsuri Master DS       DS
# 16588  16591                                   Mega Brain Boost       DS
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
# ...

# %%
data = d[["Name","Year","Publisher"]]
print(data.head(20))
# Out:
#                                             Name    Year  \
# 0                                     Wii Sports  2006.0
# 1                              Super Mario Bros.  1985.0
# 2                                 Mario Kart Wii  2008.0
# 3                              Wii Sports Resort  2009.0
# 4                       Pokemon Red/Pokemon Blue  1996.0
# 5                                         Tetris  1989.0
# 6                          New Super Mario Bros.  2006.0
# 7                                       Wii Play  2006.0
# 8                      New Super Mario Bros. Wii  2009.0
# 9                                      Duck Hunt  1984.0
# 10                                    Nintendogs  2005.0
# 11                                 Mario Kart DS  2005.0
# 12                   Pokemon Gold/Pokemon Silver  1999.0
# 13                                       Wii Fit  2007.0
# 14                                  Wii Fit Plus  2009.0
# ...

# %%
data = d[["Name","Year","Publisher"]]
print(data.tail(20))
# Out:
#                                                     Name    Year  \
# 16578                      Outdoors Unleashed: Africa 3D  2011.0
# 16579                                  PGA European Tour  2000.0
# 16580                                          Real Rode  2008.0
# 16581                                          Fit & Fun  2011.0
# 16582                                    Planet Monsters  2001.0
# 16583                                     Carmageddon 64  1999.0
# 16584                                   Bust-A-Move 3000  2003.0
# 16585                                             Breach  2011.0
# 16586                     Secret Files 2: Puritas Cordis  2009.0
# 16587                           Mezase!! Tsuri Master DS  2009.0
# 16588                                   Mega Brain Boost  2008.0
# 16589  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...  2016.0
# 16590  Eiyuu Densetsu: Sora no Kiseki Material Collec...  2007.0
# ...

# %%
data = d[["Name","NA_Sales"]]
print(data.head(20))
# Out:
#                                             Name  NA_Sales
# 0                                     Wii Sports     41.49
# 1                              Super Mario Bros.     29.08
# 2                                 Mario Kart Wii     15.85
# 3                              Wii Sports Resort     15.75
# 4                       Pokemon Red/Pokemon Blue     11.27
# 5                                         Tetris     23.20
# 6                          New Super Mario Bros.     11.38
# 7                                       Wii Play     14.03
# 8                      New Super Mario Bros. Wii     14.59
# 9                                      Duck Hunt     26.93
# 10                                    Nintendogs      9.07
# 11                                 Mario Kart DS      9.81
# 12                   Pokemon Gold/Pokemon Silver      9.00
# 13                                       Wii Fit      8.94
# 14                                  Wii Fit Plus      9.09
# ...

# %%
name = d.loc[:,"Name"]
x = name.head(20)
nasales = d.loc[:,"NA_Sales"]
y = nasales.head(20)
print("\n")
plt.xlabel("Name")
plt.ylabel("NA_Sales")
plt.plot(x,y)
plt.scatter(x,y)
plt.show()
print("\n")
plt.xlabel("Name")
plt.ylabel("NA_Sales")
plt.scatter(x,y)
plt.show()
print("\n")
plt.xlabel("Name")
plt.ylabel("NA_Sales")
plt.hist(y)
plt.show()

# %%
data = d[["Name","EU_Sales"]]
print(data.head(20))
# Out:
#                                             Name  EU_Sales
# 0                                     Wii Sports     29.02
# 1                              Super Mario Bros.      3.58
# 2                                 Mario Kart Wii     12.88
# 3                              Wii Sports Resort     11.01
# 4                       Pokemon Red/Pokemon Blue      8.89
# 5                                         Tetris      2.26
# 6                          New Super Mario Bros.      9.23
# 7                                       Wii Play      9.20
# 8                      New Super Mario Bros. Wii      7.06
# 9                                      Duck Hunt      0.63
# 10                                    Nintendogs     11.00
# 11                                 Mario Kart DS      7.57
# 12                   Pokemon Gold/Pokemon Silver      6.18
# 13                                       Wii Fit      8.03
# 14                                  Wii Fit Plus      8.59
# ...

# %%
name = d.loc[:,"Name"]
x = name.head(20)

nasales = d.loc[:,"EU_Sales"]
y = nasales.head(20)
plt.xlabel("Name")
plt.ylabel("EU_Sales")
plt.plot(x,y)
plt.scatter(x,y)
plt.show()
print("\n")
plt.xlabel("Name")
plt.ylabel("EU_Sales")
plt.scatter(x,y)
plt.show()
print("\n")
plt.xlabel("Name")
plt.ylabel("EU_Sales")
plt.hist(y)
plt.show()

# %%
data = d[["Name","JP_Sales"]]
print(data.head(20))
# Out:
#                                             Name  JP_Sales
# 0                                     Wii Sports      3.77
# 1                              Super Mario Bros.      6.81
# 2                                 Mario Kart Wii      3.79
# 3                              Wii Sports Resort      3.28
# 4                       Pokemon Red/Pokemon Blue     10.22
# 5                                         Tetris      4.22
# 6                          New Super Mario Bros.      6.50
# 7                                       Wii Play      2.93
# 8                      New Super Mario Bros. Wii      4.70
# 9                                      Duck Hunt      0.28
# 10                                    Nintendogs      1.93
# 11                                 Mario Kart DS      4.13
# 12                   Pokemon Gold/Pokemon Silver      7.20
# 13                                       Wii Fit      3.60
# 14                                  Wii Fit Plus      2.53
# ...

# %%
name = d.loc[:,"Name"]
x = name.head(20)
nasales = d.loc[:,"JP_Sales"]
y = nasales.head(20)
plt.xlabel("Name")
plt.ylabel("JP_Sales")
plt.plot(x,y)
plt.scatter(x,y)
print("\n")
plt.show()
plt.xlabel("Name")
plt.ylabel("JP_Sales")
plt.scatter(x,y)
print("\n")
plt.show()
print("\n")
plt.xlabel("Name")
plt.ylabel("JP_Sales")
plt.hist(y)
plt.show()

# %%
data = d[["Name","Other_Sales"]]
print(data.head(20))
# Out:
#                                             Name  Other_Sales
# 0                                     Wii Sports         8.46
# 1                              Super Mario Bros.         0.77
# 2                                 Mario Kart Wii         3.31
# 3                              Wii Sports Resort         2.96
# 4                       Pokemon Red/Pokemon Blue         1.00
# 5                                         Tetris         0.58
# 6                          New Super Mario Bros.         2.90
# 7                                       Wii Play         2.85
# 8                      New Super Mario Bros. Wii         2.26
# 9                                      Duck Hunt         0.47
# 10                                    Nintendogs         2.75
# 11                                 Mario Kart DS         1.92
# 12                   Pokemon Gold/Pokemon Silver         0.71
# 13                                       Wii Fit         2.15
# ...

# %%
name = d.loc[:,"Name"]
x = name.head(20)
nasales = d.loc[:,"Other_Sales"]
y = nasales.head(20)
plt.xlabel("Name")
plt.ylabel("Other_Sales")
plt.plot(x,y)
plt.scatter(x,y)
print("\n")
plt.show()
plt.xlabel("Name")
plt.ylabel("Other_Sales")
plt.scatter(x,y)
print("\n")
plt.show()
plt.xlabel("Name")
plt.ylabel("Other_Sales")
print("\n")
plt.hist(y)
plt.show()

# %%
name = d.loc[:,"Name"]
x = name.head(20)
nasales = d.loc[:,"Global_Sales"]
y = nasales.head(20)
plt.xlabel("Name")
plt.ylabel("Global_Sales")
plt.plot(x,y)
plt.scatter(x,y)
print("\n")
plt.show()
plt.xlabel("Name")
plt.ylabel("Global_Sales")
plt.scatter(x,y)
print("\n")
plt.show()
plt.xlabel("Name")
plt.ylabel("Global_Sales")
plt.hist(y)
print("\n")

plt.show()

# %%
#Linear Regression
from sklearn import linear_model
X = d[['NA_Sales','Other_Sales']]
y = d['Global_Sales']

regr = linear_model.LinearRegression()
regr.fit(X,y)

print(regr.coef_)
# Out:
# [1.4861665  2.08537549]

# %%
#Linear Regression
from sklearn import linear_model
X = d[['EU_Sales','Other_Sales']]
y = d['Global_Sales']

regr = linear_model.LinearRegression()
regr.fit(X,y)

print(regr.coef_)
# Out:
# [2.34032159 1.6151115 ]

# %%
#Linear Regression
from sklearn import linear_model
X = d[['JP_Sales','Other_Sales']]
y = d['Global_Sales']

regr = linear_model.LinearRegression()
regr.fit(X,y)

print(regr.coef_)
# Out:
# [2.16669568 5.13928915]

# %%
d.corr(method="pearson")
# Out:
#                   Rank      Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank          1.000000  0.178814 -0.401362 -0.379123 -0.267785    -0.332986
# Year          0.178814  1.000000 -0.091402  0.006014 -0.169316     0.041058
# NA_Sales     -0.401362 -0.091402  1.000000  0.767727  0.449787     0.634737
# EU_Sales     -0.379123  0.006014  0.767727  1.000000  0.435584     0.726385
# JP_Sales     -0.267785 -0.169316  0.449787  0.435584  1.000000     0.290186
# Other_Sales  -0.332986  0.041058  0.634737  0.726385  0.290186     1.000000
# Global_Sales -0.427407 -0.074735  0.941047  0.902836  0.611816     0.748331
#
#               Global_Sales
# Rank             -0.427407
# Year             -0.074735
# NA_Sales          0.941047
# EU_Sales          0.902836
# JP_Sales          0.611816
# Other_Sales       0.748331
# Global_Sales      1.000000

# %%
d.corr(method="spearman")
# Out:
#                   Rank      Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank          1.000000  0.151529 -0.795516 -0.697105 -0.151851    -0.810416
# Year          0.151529  1.000000 -0.133088 -0.057729  0.009605     0.055726
# NA_Sales     -0.795516 -0.133088  1.000000  0.681254 -0.228603     0.769432
# EU_Sales     -0.697105 -0.057729  0.681254  1.000000 -0.177486     0.766054
# JP_Sales     -0.151851  0.009605 -0.228603 -0.177486  1.000000    -0.069990
# Other_Sales  -0.810416  0.055726  0.769432  0.766054 -0.069990     1.000000
# Global_Sales -0.999622 -0.151248  0.795572  0.696846  0.151931     0.810381
#
#               Global_Sales
# Rank             -0.999622
# Year             -0.151248
# NA_Sales          0.795572
# EU_Sales          0.696846
# JP_Sales          0.151931
# Other_Sales       0.810381
# Global_Sales      1.000000

# %%
d.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Rank            8300.605254
# Year            2006.406443
# NA_Sales           0.264667
# EU_Sales           0.146652
# JP_Sales           0.077782
# Other_Sales        0.048063
# Global_Sales       0.537441
# dtype: float64

# %%
d.median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Rank            8300.50
# Year            2007.00
# NA_Sales           0.08
# EU_Sales           0.02
# JP_Sales           0.00
# Other_Sales        0.01
# Global_Sales       0.17
# dtype: float64

# %%
d.mode()
# Out:
#         Rank                         Name Platform    Year   Genre  \
# 0          1  Need for Speed: Most Wanted       DS  2009.0  Action
# 1          2                          NaN      NaN     NaN     NaN
# 2          3                          NaN      NaN     NaN     NaN
# 3          4                          NaN      NaN     NaN     NaN
# 4          5                          NaN      NaN     NaN     NaN
# ...      ...                          ...      ...     ...     ...
# 16593  16596                          NaN      NaN     NaN     NaN
# 16594  16597                          NaN      NaN     NaN     NaN
# 16595  16598                          NaN      NaN     NaN     NaN
# 16596  16599                          NaN      NaN     NaN     NaN
# 16597  16600                          NaN      NaN     NaN     NaN
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0      Electronic Arts       0.0       0.0       0.0          0.0
# ...

# %%
d.std()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Rank            4791.853933
# Year               5.828981
# NA_Sales           0.816683
# EU_Sales           0.505351
# JP_Sales           0.309291
# Other_Sales        0.188588
# Global_Sales       1.555028
# dtype: float64

# %%
d.var()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Rank            2.296186e+07
# Year            3.397702e+01
# NA_Sales        6.669712e-01
# EU_Sales        2.553799e-01
# JP_Sales        9.566070e-02
# Other_Sales     3.556559e-02
# Global_Sales    2.418112e+00
# dtype: float64

# %%
d.kurt()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Rank              -1.199865
# Year               1.848181
# NA_Sales         649.130268
# EU_Sales         756.027796
# JP_Sales         194.233994
# Other_Sales     1025.348145
# Global_Sales     603.932346
# dtype: float64

# %%
d.skew()
# Out:
# <ipython-input-16-9b5f30598e0c>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   d.skew()
# Rank             0.000066
# Year            -1.002560
# NA_Sales        18.799627
# EU_Sales        18.875535
# JP_Sales        11.206458
# Other_Sales     24.233923
# Global_Sales    17.400645
# dtype: float64

# %%
d.describe(include="all")
# Out:
#                 Rank                         Name Platform          Year  \
# count   16598.000000                        16598    16598  16327.000000
# unique           NaN                        11493       31           NaN
# top              NaN  Need for Speed: Most Wanted       DS           NaN
# freq             NaN                           12     2163           NaN
# mean     8300.605254                          NaN      NaN   2006.406443
# std      4791.853933                          NaN      NaN      5.828981
# min         1.000000                          NaN      NaN   1980.000000
# 25%      4151.250000                          NaN      NaN   2003.000000
# 50%      8300.500000                          NaN      NaN   2007.000000
# 75%     12449.750000                          NaN      NaN   2010.000000
# max     16600.000000                          NaN      NaN   2020.000000
#
#          Genre        Publisher      NA_Sales      EU_Sales      JP_Sales  \
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from matplotlib import pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns
corr = d.corr()
plt.figure(figsize=(38,16))
sns.heatmap(d.corr(),annot=True)
plt.savefig('Heatmap.png')
plt.show()

# %%
#NA_Sales
import plotly.express as px
NA_Sales=d.loc[:,"NA_Sales"]
x=NA_Sales.head(10)
Name=d.loc[:,"Name"]
y=Name.head(10)
EU_Sales=d.loc[:,"Rank"]
z=EU_Sales.head(10)
px.scatter_3d(d,x,y,z,color_discrete_map = {"Joly": "blue", "Bergeron": "violet", "Coderre": "pink"})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#EU_Sales
import plotly.express as px
EU_Sales=d.loc[:,"EU_Sales"]
x=EU_Sales.head(10)
Name=d.loc[:,"Name"]
y=Name.head(10)
JP_Sales=d.loc[:,"Rank"]
z=JP_Sales.head(10)
px.scatter_3d(d,x,y,z,color_discrete_map = {"Joly": "blue", "Bergeron": "violet", "Coderre": "pink"})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#JP_Sales
import plotly.express as px
EU_Sales=d.loc[:,"JP_Sales"]
x=EU_Sales.head(10)
Name=d.loc[:,"Name"]
y=Name.head(10)
JP_Sales=d.loc[:,"Rank"]
z=JP_Sales.head(10)
px.scatter_3d(d,x,y,z,color_discrete_map = {"Joly": "blue", "Bergeron": "violet", "Coderre": "pink"})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Other_Sales
import plotly.express as px
EU_Sales=d.loc[:,"Other_Sales"]
x=EU_Sales.head(10)
Name=d.loc[:,"Name"]
y=Name.head(10)
JP_Sales=d.loc[:,"Rank"]
z=JP_Sales.head(10)
px.scatter_3d(d,x,y,z,color_discrete_map = {"Joly": "blue", "Bergeron": "violet", "Coderre": "pink"})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Global_Sales
import plotly.express as px
EU_Sales=d.loc[:,"Global_Sales"]
x=EU_Sales.head(10)
Name=d.loc[:,"Name"]
y=Name.head(10)
JP_Sales=d.loc[:,"Rank"]
z=JP_Sales.head(10)
px.scatter_3d(d,x,y,z,color_discrete_map = {"Joly": "blue", "Bergeron": "violet", "Coderre": "pink"})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#LOGISTIC REGRESSION
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from matplotlib import pyplot as plot
import matplotlib.colors as mcolors
import seaborn as sns
path = '/content/drive/MyDrive/FODS Mini Project/Data Science Mini project/Analysing-movie-data-set-using-python/vgsales.csv'
data = pd.read_csv(path)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
sum(data.duplicated())
# Out:
# 0

# %%
#logistic reguression
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
nb_samples = 1000
x, y = make_classification(n_samples=nb_samples, n_features=2, n_informative=2, n_redundant=0, n_clusters_per_class=1)
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)
model = LogisticRegression()
model.fit(xtrain, ytrain)
# Out:
# LogisticRegression()

# %%
#Accuracy of the data
print(accuracy_score(ytest, model.predict(xtest)))
# Out:
# 0.91
